# %%
from store_sim_agent.agent import app
# Out:
# Extra fields {'max_connections'} in GigaChat class

# %%
from store_sim_agent.agent import AgentState
from langchain.messages import HumanMessage

state = AgentState(messages=[HumanMessage(content="Знаешь что-нибудь про клиента cust#1?")])


response = await app.ainvoke(state)
# Out:
# 2026-02-17 17:44:01.428 | DEBUG    | store_sim_agent.agent:agent:30 - PingMCP
# 2026-02-17 17:44:01.428 | DEBUG    | store_sim_agent.agent:agent:31 - Listing tools
# 2026-02-17 17:44:01.478 | DEBUG    | store_sim_agent.agent:agent:34 - Got tools. len=5
# ...

# %%
response
# Out:
# {'messages': [HumanMessage(content='Знаешь что-нибудь про клиента cust#1?', additional_kwargs={}, response_metadata={}, id='30796fa0-9375-4ab9-9091-6b5409d3430a'),
# ...
