# %%
from fastmcp import Client

client = Client("http://localhost:8001/mcp")

# %%
async with client:
    tools = await client.list_tools()

# %%
tools
# Out:
# [Tool(name='get_customer_info', title=None, description='Search for a customer by their ID and return their information.', inputSchema={'properties': {'customer_id': {'type': 'string'}}, 'required': ['customer_id'], 'type': 'object'}, outputSchema={'properties': {'result': {'type': 'string'}}, 'required': ['result'], 'type': 'object', 'x-fastmcp-wrap-result': True}, icons=None, annotations=None, meta={'_fastmcp': {'tags': []}}, execution=None),
#  Tool(name='get_order_info', title=None, description='Search for an order by its ID and return its information.', inputSchema={'properties': {'order_id': {'type': 'string'}}, 'required': ['order_id'], 'type': 'object'}, outputSchema={'properties': {'result': {'type': 'string'}}, 'required': ['result'], 'type': 'object', 'x-fastmcp-wrap-result': True}, icons=None, annotations=None, meta={'_fastmcp': {'tags': []}}, execution=None),
# ...
